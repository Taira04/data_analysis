# %%
# 2-5-1 Matplotlibを使うための準備

# %%
# Matplotlib　と　Seabornの読みこみ
# Seabornはきれいに図示できる
import matplotlib as mpl
import seaborn as sns

# pyplotにはpltの別名で実行できるようにする
import matplotlib.pyplot as plt

# Jupyter Notebook上でグラフを表示させるために必要なマジックコマンド
# %matplotlib inline

# numpyの読み込み
import numpy as np
from numpy import random

# %%
# 2-5-2 散布図

# %%
# 散布図

# シード値の固定
random.seed(0)

# x軸のデータ
x = np.random.randn(30)

# y軸のデータ
y = np.sin(x) + np.random.randn(30)

# グラフの大きさ指定
plt.figure(figsize=(15, 10))

# グラフの描写
plt.plot(x, y, 'o')

# %%
# 以下でも散布図が描ける
plt.scatter(x,y)

# タイトル
plt.title('Title Name')

# xの座標名
plt.xlabel('x')

# yの座標名
plt.ylabel('y')

# grid(グラフ内の縦横線)の表示
plt.grid(True)

# %%
# タイトル
plt.title('Title Name')

# xの座標名
plt.xlabel('x')

# yの座標名
plt.ylabel('y')

# grid(グラフ内の縦横線)の表示
plt.grid(True)

# %%
# 以下でも散布図が描ける
plt.scatter(x,y)

# %%
# 連続曲線

# シード値の指定
np.random.seed(0)

# データの範囲
numpy_data_x = np.arange(1000)

# 乱数の発生と積み上げ
numpy_random_data_y = np.random.randn(1000).cumsum()

# グラフの大きさを指定
plt.figure(figsize=(20,6))

# ラベルつける
plt.plot(numpy_data_x, numpy_random_data_y, label='Label')
plt.legend()

# %%
# 連続曲線

# シード値の指定
np.random.seed(0)

# データの範囲
numpy_data_x = np.arange(1000)

# 乱数の発生と積み上げ
numpy_random_data_y = np.random.randn(1000).cumsum()

# グラフの大きさを指定
plt.figure(figsize=(20,6))

# ラベルつける
plt.plot(numpy_data_x, numpy_random_data_y, label='Label')
plt.legend()

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

# %%
# 2-5-3　グラフの分割

# %%
# グラフの大きさを指定
plt.figure(figsize=(20,6))

# 2行１列のグラフの１つ目
plt.subplot(2,1,1)
x = np.linspace(-10, 10, 100)
plt.plot(x, np.sin(x))

# 2行１列のグラフの2つ目
plt.subplot(2,1,2)
y = np.linspace(-10, 10, 100)
plt.plot(y,np.sin(2*y))

plt.grid(True)

# %%
# 2-5-4 関数グラフの描画

# %%
# f(x) = x^2 + 2x + 1　を表示
# 関数の定義
def my_function(x):
    return x ** 2 + 2 * x + 1

x = np.arange(-10,10)
plt.figure(figsize=(20,6))
plt.plot(x, my_function(x))
plt.grid(True)

# %%
# 2-5-5 ヒストグラム

# %%
# シードの固定
random.seed(0)

# グラフの大きさ指定
plt.figure(figsize = (20, 6))

# ヒストグラムの描写(対象データ, ビンのサイズ, 範囲)
plt.hist(np.random.randn(10 ** 5) * 10 + 50, bins = 60, range = (20, 80))

plt.grid(True)

# %%
# 利用できるパラメータの確認
# ?plt.hist

# %%
# 練習2-10 y = 5x + 3(xは-10から10)

# 必要なライブラリのインストール
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from numpy import random

# %matplotlib inline

# %%
# 関数定義
def my_function(x):
    return 5 * x + 3

# xの範囲を指定
x = np.arange(-10, 10)

# 図表サイズ指定
plt.figure(figsize=(20,6))

# 図示
plt.plot(x, my_function(x))

# グリッド表示
plt.grid(True)

# %%
# 解答
x = np.linspace(-10, 10,100)
plt.plot(x, 5*x + 3)
plt.xlabel("X value")
plt.ylabel("Y value")
plt.grid(True)

# %%
# <練習問題 2-11> 「 𝑦=𝑠𝑖𝑛(𝑥) 」と「 𝑦=𝑐𝑜𝑠(𝑥) 」のグラフを重ねて描いてください（ 𝑥 は-10から10の値）

# %%
# xの範囲を指定
x = np.linspace(-10, 10, 100)

# 図示
plt.plot(x , np.sin(x))
plt.plot(x , np.cos(x))

# グリッド追加
plt.grid(True)

# %%
# <練習問題 2-12>
# 0から1の値をとる一様乱数を1,000個、2組発生させて、それぞれのヒストグラムを描いてみましょう。
# なお、それぞれのヒストグラムを別のグラフに表示するために、plt.subplotを利用してください。
# また、ここで一様乱数とは、ある数から別のある数まで等確率で発生する乱数のことをいい、np.random.uniformを使います。
# たとえば、0から1までの数を10個発生させる場合は、np.random.uniform(0.0, 1.0, 10)とします。
# また、1,000個だけではなく、100個や10,000個などでも実施してみましょう。何かわかることはありますか。

# %%
import math

def uni_hist(N):
    # 一様乱数の発生
    x = np.random.uniform(0.0, 1.0, N)
    y = np.random.uniform(0.0, 1.0, N)
    
    plt.subplot(2,1,1)
    plt.hist(x)
    plt.title('No1:histogram')
    plt.grid(True)
    
    plt.subplot(2,1,2)
    plt.hist(y)
    plt.title('No2:histogram')
    plt.grid(True)
    
    plt.tight_layout()

uni_hist(100)

# %%
uni_hist(1000)

# %%
uni_hist(10000)
